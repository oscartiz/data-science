# %% [markdown]
# # Shoe Sales Dataset Exploration
#
# This notebook provides a preliminary look at the `shoes_sales_dataset.csv`.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set plotting style
sns.set_theme(style="whitegrid")

# Load the dataset
df = pd.read_csv('data/shoes_sales_dataset.csv')

# Display the first few rows
df.head()
# Out:
#   Sale_ID        Date        Brand Shoe_Type  Color Country Sales_Channel  \
# 0      S1  2025-11-24         Nike     Boots   Blue      UK        Online
# 1      S2  2025-03-13     Skechers     Boots   Grey     USA          Mall
# 2      S3  2025-08-05         Nike   Running  White      UK          Mall
# 3      S4  2025-11-05  New Balance    Casual  Green     UAE          Mall
# 4      S5  2025-10-07       Adidas    Formal   Grey  France        Online
#
#    Price_USD  Units_Sold  Revenue_USD
# 0     112.40           4       449.60
# 1     239.16           4       956.64
# 2     191.04           2       382.08
# 3     161.70           1       161.70
# 4      64.32          14       900.48

# %%
# Basic information about the dataset
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sale_ID        1000 non-null   str
#  1   Date           1000 non-null   str
#  2   Brand          1000 non-null   str
#  3   Shoe_Type      1000 non-null   str
#  4   Color          1000 non-null   str
#  5   Country        1000 non-null   str
#  6   Sales_Channel  1000 non-null   str
#  7   Price_USD      1000 non-null   float64
#  8   Units_Sold     1000 non-null   int64
#  9   Revenue_USD    1000 non-null   float64
# dtypes: float64(2), int64(1), str(7)
# memory usage: 78.3 KB

# %%
# Descriptive statistics
df.describe()
# Out:
#          Price_USD   Units_Sold  Revenue_USD
# count  1000.000000  1000.000000   1000.00000
# mean    137.856420    10.584000   1453.18603
# std      64.270059     5.842181   1112.32648
# min      31.020000     1.000000     32.38000
# 25%      81.915000     6.000000    561.05000
# 50%     139.295000    10.000000   1132.62500
# 75%     193.752500    16.000000   2163.35000
# max     249.940000    20.000000   4938.40000

# %% [markdown]
# ## Visualizations

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Brand', order=df['Brand'].value_counts().index, palette='viridis')
plt.title('Number of Sales by Brand')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.show()
# Out:
# /var/folders/_m/2zh14fhs0ln6301p0vj1bzc80000gn/T/ipykernel_14299/665981743.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Brand', order=df['Brand'].value_counts().index, palette='viridis')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Brand', y='Revenue_USD', estimator=sum, errorbar=None, order=df.groupby('Brand')['Revenue_USD'].sum().sort_values(ascending=False).index, palette='mako')
plt.title('Total Revenue by Brand')
plt.xlabel('Brand')
plt.ylabel('Total Revenue (USD)')
plt.show()
# Out:
# /var/folders/_m/2zh14fhs0ln6301p0vj1bzc80000gn/T/ipykernel_14299/246141075.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Brand', y='Revenue_USD', estimator=sum, errorbar=None, order=df.groupby('Brand')['Revenue_USD'].sum().sort_values(ascending=False).index, palette='mako')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Shoe_Type', order=df['Shoe_Type'].value_counts().index, palette='rocket')
plt.title('Number of Sales by Shoe Type')
plt.xlabel('Shoe Type')
plt.ylabel('Count')
plt.show()
# Out:
# /var/folders/_m/2zh14fhs0ln6301p0vj1bzc80000gn/T/ipykernel_14299/533163495.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Shoe_Type', order=df['Shoe_Type'].value_counts().index, palette='rocket')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Sales_Channel', y='Price_USD', palette='coolwarm')
plt.title('Price Distribution by Sales Channel')
plt.xlabel('Sales Channel')
plt.ylabel('Price (USD)')
plt.show()
# Out:
# /var/folders/_m/2zh14fhs0ln6301p0vj1bzc80000gn/T/ipykernel_14299/2731994122.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Sales_Channel', y='Price_USD', palette='coolwarm')
